# %% [markdown]
# # Data science colleges

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanswanstrom/awesome-datascience-colleges/master/data_science_colleges.csv')

# %%
df.head()
# Out:
#                       SCHOOL  \
# 0          Auburn University
# 1          Auburn University
# 2  The University of Alabama
# 3  The University of Alabama
# 4  The University of Alabama
#
#                                              PROGRAM DEGREE ONLINE ONCAMPUS  \
# 0  Online Master of Business Administration with ...      M      F        T
# 1                                       Data Science      B      F        T
# 2  Master of Science in Marketing, Specialization...      M      T        F
# 3  MS in Operations Management - Decision Analyti...      M      F        T
# 4  M.S. degree in Applied Statistics, Data Mining...      M      F        T
#
#   COUNTRY STATE        CITY                              DEPARTMENT  \
# 0      US    AL      Auburn  Raymond J. Harbert College of Business
# 1      US    AL      Auburn                                Business
# 2      US    AL  Tuscaloosa   Manderson Graduate School of Business
# ...

# %%
df['State']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-89ca2dcc0f12> in <module>()
# ----> 1 df['State']
#
# ...

# %%
df.head()
# Out:
#                       SCHOOL  \
# 0          Auburn University
# 1          Auburn University
# 2  The University of Alabama
# 3  The University of Alabama
# 4  The University of Alabama
#
#                                              PROGRAM DEGREE ONLINE ONCAMPUS  \
# 0  Online Master of Business Administration with ...      M      F        T
# 1                                       Data Science      B      F        T
# 2  Master of Science in Marketing, Specialization...      M      T        F
# 3  MS in Operations Management - Decision Analyti...      M      F        T
# 4  M.S. degree in Applied Statistics, Data Mining...      M      F        T
#
#   COUNTRY STATE        CITY                              DEPARTMENT  \
# 0      US    AL      Auburn  Raymond J. Harbert College of Business
# 1      US    AL      Auburn                                Business
# 2      US    AL  Tuscaloosa   Manderson Graduate School of Business
# ...

# %%
df.iloc[10:21]
# Out:
#                                      SCHOOL  \
# 10    University of Arkansas at Little Rock
# 11    University of Arkansas at Little Rock
# 12                 Arizona State University
# 13                 Arizona State University
# 14                 Arizona State University
# 15                 Arizona State University
# 16                    University of Arizona
# 17  California Polytechnic State University
# 18  California Polytechnic State University
# 19     California State University-East Bay
# 20    California State University-Fullerton
#
#                                               PROGRAM DEGREE ONLINE ONCAMPUS  \
# 10                        Information Quality Program      M      F        T
# 11                    Information Quality Program PhD      D      F        T
# 12             Advanced Analytics in Higher Education      C      T        F
# 13                                 Business Analytics      M      F        T
# ...

# %%
df[(df['STATE'].isin(['WA', 'NY', 'CA', 'PA']) & ('Data Science' in str(df['PROGRAM']))) | (df['SCHOOL'].isin(['University of California-San Diego', 'Carnegie Mellon University']))]
# Out:
#                                                SCHOOL  \
# 17            California Polytechnic State University
# 18            California Polytechnic State University
# 19               California State University-East Bay
# 20              California State University-Fullerton
# 21              California State University-Fullerton
# 22              California State University-Fullerton
# 23              California State University-Fullerton
# 24             California State University-Long Beach
# 25         California State University-San Bernardino
# 26                                 Chapman University
# 27                                 Chapman University
# 28                      Claremont Graduate University
# 29                                        Galvanize U
# 30                                National University
# 31                                National University
# 32                          San Jose State University
# ...

# %%
# df[(df['STATE'].isin(['WA', 'NY', 'CA', 'PA']) & df['PROGRAM'].str.contains('Data Science')) | (df['SCHOOL'].isin(['University of California-San Diego', 'Carnegie Mellon University']))]
# Out:
#                                           SCHOOL  \
# 17       California Polytechnic State University
# 21         California State University-Fullerton
# 26                            Chapman University
# 27                            Chapman University
# 28                 Claremont Graduate University
# 33                        Santa Clara University
# 38                           Stanford University
# 42               University of California-Irvine
# 45            University of California-San Diego
# 46            University of California-San Diego
# 47            University of California-San Diego
# 48             University of California-Berkeley
# 50             University of California-Berkeley
# 53                   University Of San Francisco
# 54             University of Southern California
# 282  Columbia University in the City of New York
# 293                           Cornell University
# 302                          New York University
# ...
