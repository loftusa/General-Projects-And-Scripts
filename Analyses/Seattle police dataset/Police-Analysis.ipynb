# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# %pwd
# Out:
# 'C:\\Users\\Alex Loftus\\Dropbox\\Programming\\Projects\\Jupyter-Notebooks\\Analyses\\Seattle police dataset'

# %%
df = pd.read_csv('../../datasets/Seattle-Police-Reports.csv')
df.head()
# Out:
#    RMS CDW ID  General Offense Number Offense Code  Offense Code Extension  \
# 0     1032236              2012163025         2303                       0
# 1     1032237              2012198841         2399                       3
# 2     1032238               201472111         2404                       8
# 3     1032239              2014107311         2202                       0
# 4     1032241              2014123990         2404                       1
#
#          Offense Type Summary Offense Code Summarized Offense Description  \
# 0      THEFT-SHOPLIFT                 2300                    SHOPLIFTING
# 1           THEFT-OTH                 2300                 OTHER PROPERTY
# 2     VEH-THEFT-TRUCK                 2400                  VEHICLE THEFT
# 3  BURGLARY-FORCE-RES                 2200                       BURGLARY
# 4      VEH-THEFT-AUTO                 2400                  VEHICLE THEFT
#
#             Date Reported Occurred Date or Date Range Start  \
# ...
