# %% [markdown]
# # Customizing ticks

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import sklearn

# %%
ax = plt.axes(xscale='log', yscale='log')
ax.set_xlim(1, 10E8)
ax.set_ylim(1, 10E8)
# Out:
# (1, 1000000000.0)

# %%
# Hiding ticks and labels
ax = plt.axes()
ax.plot(np.random.rand(50))

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(5, 5, figsize=(10,10))
fig.subplots_adjust(wspace=0, hspace=0)

# Get face data
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces().images
for i in range(5):
    for j in range(5):
        ax[i, j].xaxis.set_major_locator(plt.NullLocator())
        ax[i, j].yaxis.set_major_locator(plt.NullLocator())
        ax[i, j].imshow(faces[10 * i + j], cmap='bone')

# %% [markdown]
# ## Changing number of ticks

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MaxNLocator(1))
    axi.yaxis.set_major_locator(plt.MaxNLocator(1))

# %% [markdown]
# ## Fancy tick formats

# %%
# plot sin and cosine curve
fig, ax = plt.subplots()
x = np.linspace(0, 3*np.pi, 1000)

plt.plot(x, np.cos(x), lw=3, label='Cos')
plt.plot(x, np.sin(x), lw=3, label='Sin')

ax.grid(True)
ax.legend(frameon=False)
ax.axis('equal')
ax.set_xlim(0, 3*np.pi)

ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))
ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 4))

def format_func(value, tick_number):  # Could have made it a function that replaces shit with stuff that looks like pi
    return 1

ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
