# %% [markdown]
# # Density and Contour Plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# Displaying 3-dimensional data using contours or colors.

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)


X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.contour(X, Y, Z, cmap='RdGy')

# %%
plt.contourf(X, Y, Z, 100, cmap='RdGy')
plt.colorbar()

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image')
plt.grid(False)

# %%
import pandas as pd

# %%
pd.DataFrame(Z).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.839072 -0.834707 -0.821659 -0.800056 -0.770046 -0.731440 -0.682732
# 1 -0.839072 -0.829027 -0.810387 -0.783465 -0.748587 -0.705743 -0.653597
# 2 -0.839072 -0.823257 -0.798765 -0.766110 -0.725830 -0.678132 -0.621896
# 3 -0.839072 -0.817397 -0.786795 -0.748006 -0.701814 -0.648682 -0.587753
# 4 -0.839072 -0.811449 -0.774485 -0.729174 -0.676580 -0.617471 -0.551302
#
#          7         8         9     ...           40        41        42  \
# 0 -0.619418 -0.532503 -0.409059    ...     0.612843  0.653605  0.738150
# 1 -0.587802 -0.499509 -0.375917    ...     0.440742  0.501995  0.610121
# 2 -0.552987 -0.462759 -0.338597    ...     0.213461  0.301626  0.440831
# 3 -0.515159 -0.422507 -0.297424    ...    -0.030143  0.088465  0.262145
# 4 -0.474518 -0.379032 -0.252761    ...    -0.248419 -0.099227  0.107692
#
#          43        44        45        46        47        48        49
# 0  0.852447  0.964180  1.030656  1.013820  0.895671  0.686173  0.419407
# 1  0.750946  0.891961  0.990235  1.007431  0.925224  0.753213  0.525082
# 2  0.616694  0.796433  0.936776  0.998985  0.964274  0.841727  0.664464
# 3  0.476158  0.697299  0.881802  0.990381  1.003652  0.930059  0.802052
# 4  0.357042  0.615004  0.837163  0.983558  1.034116  0.996602  0.902801
#
# [5 rows x 50 columns]

# %%
plt.imshow(Z)

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=12)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
